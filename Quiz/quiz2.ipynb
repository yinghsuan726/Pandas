# %%
import pandas as pd
from pandas import DataFrame

# %%
h1=pd.read_csv('h1.csv')

# %%
h2=pd.read_csv('h2.csv')

# %% [markdown]
# # A

# %%
h1.shape
# h1: row = 303, col = 8
# Out:
# (303, 8)

# %%
h2.shape
# h2; row = 303, col = 8
# Out:
# (303, 8)

# %% [markdown]
# # B

# %%
h1.head(5)
# Out:
#    id  age  sex  cp  trestbps  chol  fbs  restecg
# 0   1   63    1   3       145   233    1        0
# 1   2   37    1   2       130   250    0        1
# 2   3   41    0   1       130   204    0        0
# 3   4   56    1   1       120   236    0        1
# 4   5   57    0   0       120   354    0        1

# %% [markdown]
# # C

# %%
h2.tail(10)
# Out:
#       id  thalach  exang  oldpeak  slope  ca  thal  target
# 293  294      150      0      0.8      1   0     3       0
# 294  295      144      1      2.8      0   0     1       0
# 295  296      144      1      4.0      2   2     3       0
# 296  297      136      1      0.0      1   0     2       0
# 297  298       90      0      1.0      1   2     1       0
# 298  299      123      1      0.2      1   0     3       0
# 299  300      132      0      1.2      1   0     3       0
# 300  301      141      0      3.4      1   2     3       0
# 301  302      115      1      1.2      1   1     3       0
# 302  303      174      0      0.0      1   1     2       0

# %% [markdown]
# # D

# %%
h1.id.nunique() 
# 303
# Out:
# 303

# %%
h2.id.nunique() 
# 303
# Out:
# 303

# %% [markdown]
# # E

# %%
h1.columns
# Out:
# Index(['id', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg'], dtype='object')

# %%
h2.columns
# Out:
# Index(['id', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'], dtype='object')

# %% [markdown]
# # F

# %%
h_merged = pd.merge(h1, h2)
h_merged
# column='id' is the primary key for merging
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      1   63    1   3       145   233    1        0      150      0      2.3
# 1      2   37    1   2       130   250    0        1      187      0      3.5
# 2      3   41    0   1       130   204    0        0      172      0      1.4
# 3      4   56    1   1       120   236    0        1      178      0      0.8
# 4      5   57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298  299   57    0   0       140   241    0        1      123      1      0.2
# 299  300   45    1   3       110   264    0        1      132      0      1.2
# 300  301   68    1   0       144   193    1        1      141      0      3.4
# 301  302   57    1   0       130   131    0        1      115      1      1.2
# 302  303   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %% [markdown]
# # G

# %%
h_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        303 non-null    int64
#  1   age       303 non-null    int64
#  2   sex       303 non-null    int64
#  3   cp        303 non-null    int64
#  4   trestbps  303 non-null    int64
#  5   chol      303 non-null    int64
#  6   fbs       303 non-null    int64
#  7   restecg   303 non-null    int64
#  8   thalach   303 non-null    int64
#  9   exang     303 non-null    int64
#  10  oldpeak   303 non-null    float64
#  11  slope     303 non-null    int64
#  12  ca        303 non-null    int64
#  13  thal      303 non-null    int64
#  14  target    303 non-null    int64
# dtypes: float64(1), int64(14)
# memory usage: 37.9 KB

# %% [markdown]
# # H

# %%
female_h = h_merged[h_merged['sex'] == 0]
female_h
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2      3   41    0   1       130   204    0        0      172      0      1.4
# 4      5   57    0   0       120   354    0        1      163      1      0.6
# 6      7   56    0   1       140   294    0        0      153      0      1.3
# 11    12   48    0   2       130   275    0        1      139      0      0.2
# 14    15   58    0   3       150   283    1        0      162      0      1.0
# ..   ...  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 289  290   55    0   0       128   205    0        2      130      1      2.0
# 292  293   58    0   0       170   225    1        0      146      1      2.8
# 296  297   63    0   0       124   197    0        1      136      1      0.0
# 298  299   57    0   0       140   241    0        1      123      1      0.2
# 302  303   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %%
female_h.shape
# 96
# Out:
# (96, 15)

# %% [markdown]
# # I

# %%
male_h = h_merged[h_merged['sex'] == 1]
male_h
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      1   63    1   3       145   233    1        0      150      0      2.3
# 1      2   37    1   2       130   250    0        1      187      0      3.5
# 3      4   56    1   1       120   236    0        1      178      0      0.8
# 5      6   57    1   0       140   192    0        1      148      0      0.4
# 7      8   44    1   1       120   263    0        1      173      0      0.0
# ..   ...  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 295  296   63    1   0       140   187    0        0      144      1      4.0
# 297  298   59    1   0       164   176    1        0       90      0      1.0
# 299  300   45    1   3       110   264    0        1      132      0      1.2
# 300  301   68    1   0       144   193    1        1      141      0      3.4
# 301  302   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# ...

# %%
male_h.shape
# 207
# Out:
# (207, 15)

# %% [markdown]
# # J

# %%
male_h.mean()
# Out:
# id          163.980676
# age          53.758454
# sex           1.000000
# cp            0.932367
# trestbps    130.946860
# chol        239.289855
# fbs           0.159420
# restecg       0.507246
# thalach     148.961353
# exang         0.371981
# oldpeak       1.115459
# slope         1.386473
# ca            0.811594
# thal          2.400966
# target        0.449275
# dtype: float64

# %%
female_h.mean()
# Out:
# id          126.166667
# age          55.677083
# sex           0.000000
# cp            1.041667
# trestbps    133.083333
# chol        261.302083
# fbs           0.125000
# restecg       0.572917
# thalach     151.125000
# exang         0.229167
# oldpeak       0.876042
# slope         1.427083
# ca            0.552083
# thal          2.125000
# target        0.750000
# dtype: float64

# %%
# non

# %% [markdown]
# # K

# %%
male_chol = male_h[male_h['chol'] < 239.289855]
male_chol
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      1   63    1   3       145   233    1        0      150      0      2.3
# 3      4   56    1   1       120   236    0        1      178      0      0.8
# 5      6   57    1   0       140   192    0        1      148      0      0.4
# 8      9   52    1   2       172   199    1        1      162      0      0.5
# 9     10   57    1   2       150   168    0        1      174      0      1.6
# ..   ...  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 294  295   44    1   0       120   169    0        1      144      1      2.8
# 295  296   63    1   0       140   187    0        0      144      1      4.0
# 297  298   59    1   0       164   176    1        0       90      0      1.0
# 300  301   68    1   0       144   193    1        1      141      0      3.4
# 301  302   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# ...

# %%
male_h['chol'] < 239.289855
# Out:
# 0       True
# 1      False
# 3       True
# 5       True
# 7      False
#        ...
# 295     True
# 297     True
# 299    False
# 300     True
# 301     True
# Name: chol, Length: 207, dtype: bool

# %%
male_chol = male_h[male_h['chol'] < 239.289855]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 male_chol = male_h[['chol'] < 239.289855]
#
# TypeError: '<' not supported between instances of 'list' and 'float'

# %%
female_trestbps = female_h[female_h['trestbps'] > 133.083333]
female_trestbps
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 6      7   56    0   1       140   294    0        0      153      0      1.3
# 14    15   58    0   3       150   283    1        0      162      0      1.0
# 17    18   66    0   3       150   226    0        1      114      0      2.6
# 19    20   69    0   3       140   239    0        1      151      0      1.8
# 25    26   71    0   1       160   302    0        1      162      0      0.4
# 28    29   65    0   2       140   417    1        0      157      0      0.8
# 35    36   46    0   2       142   177    0        0      160      1      1.4
# 36    37   54    0   2       135   304    1        1      170      0      0.0
# 38    39   65    0   2       155   269    0        1      148      0      0.8
# 39    40   65    0   2       160   360    0        0      151      0      0.8
# 40    41   51    0   2       140   308    0        0      142      0      1.5
# ...

# %% [markdown]
# # DONE
